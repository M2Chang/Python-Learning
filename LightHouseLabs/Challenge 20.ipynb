# %%
#Scatterplots

import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('boardgames.csv')
df.head(3)
# Out:
#    rank                                            bgg_url  game_id  \
# 0     1  https://boardgamegeek.com/boardgame/174430/glo...   174430
# 1     2  https://boardgamegeek.com/boardgame/161936/pan...   161936
# 2     3  https://boardgamegeek.com/boardgame/182028/thr...   182028
#
#                                            names  min_players  max_players  \
# 0                                     Gloomhaven            1            4
# 1                      Pandemic Legacy: Season 1            2            4
# 2  Through the Ages: A New Story of Civilization            2            4
#
#    avg_time  min_time  max_time  year  avg_rating  geek_rating  num_votes  \
# 0       120        60       120  2017     8.98893      8.61858      15376
# 1        60        60        60  2015     8.66140      8.50163      26063
# 2       240       180       240  2015     8.60673      8.30183      12352
#
#                                            image_url  age  \
# 0  https://cf.geekdo-images.com/original/img/lDN3...   12
# 1  https://cf.geekdo-images.com/original/img/P_Sw...   13
# 2  https://cf.geekdo-images.com/original/img/1d2h...   14
#
#                                             mechanic  owned  \
# 0  Action / Movement Programming, Co-operative Pl...  25928
# 1  Action Point Allowance System, Co-operative Pl...  41605
# 2  Action Point Allowance System, Auction/Bidding...  15848
#
#                                             category  \
# 0  Adventure, Exploration, Fantasy, Fighting, Min...
# 1                             Environmental, Medical
# 2                  Card Game, Civilization, Economic
#
#                    designer  weight
# 0            Isaac Childres  3.7543
# 1  Rob Daviau, Matt Leacock  2.8210
# 2            Vlaada Chvátil  4.3678

# %%
#What kind of correlation is there between the weight and avg_rating?

plt.figure()
plt.scatter(x = df['weight'], y = df['avg_rating'])
plt.show()

#looks to be positive

# %%
#What is the correlation coefficient between the two columns?

df.corr()
# Out:
#                  rank   game_id  min_players  max_players  avg_time  min_time  \
# rank         1.000000 -0.029686     0.021409     0.018707  0.011602  0.021634
# game_id     -0.029686  1.000000    -0.144871     0.016250 -0.064498 -0.104995
# min_players  0.021409 -0.144871     1.000000     0.158905 -0.049665 -0.022629
# max_players  0.018707  0.016250     0.158905     1.000000 -0.022040 -0.020897
# avg_time     0.011602 -0.064498    -0.049665    -0.022040  1.000000  0.659931
# min_time     0.021634 -0.104995    -0.022629    -0.020897  0.659931  1.000000
# max_time     0.010972 -0.065314    -0.049235    -0.022011  0.999926  0.659825
# year        -0.007448  0.103455     0.007135     0.006533  0.003830  0.003850
# avg_rating  -0.385495  0.301063    -0.216454    -0.067922  0.161758  0.116633
# geek_rating -0.886759  0.055626    -0.040871    -0.022980 -0.011703 -0.020554
# num_votes   -0.462693 -0.077227     0.020947     0.006934 -0.025939 -0.029580
# age         -0.143138  0.096223    -0.004194    -0.003500  0.025333  0.027504
# owned       -0.465226 -0.039391     0.007918     0.007676 -0.024539 -0.028970
# weight      -0.164812 -0.092998    -0.197029    -0.136169  0.233859  0.234898
#
#              max_time      year  avg_rating  geek_rating  num_votes       age  \
# rank         0.010972 -0.007448   -0.385495    -0.886759  -0.462693 -0.143138
# game_id     -0.065314  0.103455    0.301063     0.055626  -0.077227  0.096223
# min_players -0.049235  0.007135   -0.216454    -0.040871   0.020947 -0.004194
# max_players -0.022011  0.006533   -0.067922    -0.022980   0.006934 -0.003500
# avg_time     0.999926  0.003830    0.161758    -0.011703  -0.025939  0.025333
# min_time     0.659825  0.003850    0.116633    -0.020554  -0.029580  0.027504
# max_time     1.000000  0.003735    0.161214    -0.011179  -0.025618  0.025193
# year         0.003735  1.000000    0.020707     0.008029  -0.016072  0.098132
# avg_rating   0.161214  0.020707    1.000000     0.456277   0.165803  0.156797
# geek_rating -0.011179  0.008029    0.456277     1.000000   0.637970  0.163270
# num_votes   -0.025618 -0.016072    0.165803     0.637970   1.000000  0.045512
# age          0.025193  0.098132    0.156797     0.163270   0.045512  1.000000
# owned       -0.024241 -0.013931    0.165117     0.629538   0.984790  0.052791
# weight       0.233712  0.003438    0.547244     0.203591   0.014468  0.303283
#
#                 owned    weight
# rank        -0.465226 -0.164812
# game_id     -0.039391 -0.092998
# min_players  0.007918 -0.197029
# max_players  0.007676 -0.136169
# avg_time    -0.024539  0.233859
# min_time    -0.028970  0.234898
# max_time    -0.024241  0.233712
# year        -0.013931  0.003438
# avg_rating   0.165117  0.547244
# geek_rating  0.629538  0.203591
# num_votes    0.984790  0.014468
# age          0.052791  0.303283
# owned        1.000000  0.006033
# weight       0.006033  1.000000

# %%
#0.547244
