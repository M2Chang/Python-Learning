# %%
#Matplotlib Stylistic Methods

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('boardgames.csv')
df.head(2)
# Out:
#    rank                                            bgg_url  game_id  \
# 0     1  https://boardgamegeek.com/boardgame/174430/glo...   174430
# 1     2  https://boardgamegeek.com/boardgame/161936/pan...   161936
#
#                        names  min_players  max_players  avg_time  min_time  \
# 0                 Gloomhaven            1            4       120        60
# 1  Pandemic Legacy: Season 1            2            4        60        60
#
#    max_time  year  avg_rating  geek_rating  num_votes  \
# 0       120  2017     8.98893      8.61858      15376
# 1        60  2015     8.66140      8.50163      26063
#
#                                            image_url  age  \
# 0  https://cf.geekdo-images.com/original/img/lDN3...   12
# 1  https://cf.geekdo-images.com/original/img/P_Sw...   13
#
#                                             mechanic  owned  \
# 0  Action / Movement Programming, Co-operative Pl...  25928
# 1  Action Point Allowance System, Co-operative Pl...  41605
#
# ...

# %%
agefilter = df['age'] >= 13

df_filter = df[agefilter]

# %%
plt.figure(figsize = (14,7))
plt.bar(df.category.value_counts().head().index ,height = df.category.value_counts().head(), color = 'blue')
plt.title('This is a bar plot!', fontsize =14) #Specifying a title
plt.xlabel('This is the x axis!', fontsize = 14)
plt.xticks(rotation = 'vertical')
plt.ylabel('This it the y axis!', fontsize = 14)
plt.show()

# %%
plt.figure(figsize = (14,7))
plt.bar(df_filter.category.value_counts().head().index ,height = df.category.value_counts().head(), color = 'black')
plt.title('This is a bar plot!', fontsize =16) #Specifying a title
plt.xlabel('This is the x axis!', fontsize = 14)
plt.xticks(rotation = 'vertical')
plt.ylabel('This it the y axis!', fontsize = 14)
plt.show()
